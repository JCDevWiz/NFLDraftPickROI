# %%
import nflreadpy as nfl
import pandas as pd
import seaborn as sns
import sqlalchemy as sql
import matplotlib.pyplot as plt

# %%
draft = pd.read_csv('../data/draftpicks.csv')

# %%
draft
# Out:
#       Unnamed: 0  season  round  pick team              name    hof position  \
# 0           6026    2000      1     1  CLE    Courtney Brown  False       DE
# 1           6027    2000      1     2  WAS   LaVar Arrington  False       LB
# 2           6028    2000      1     3  WAS     Chris Samuels  False        T
# 3           6029    2000      1     4  CIN     Peter Warrick  False       WR
# 4           6030    2000      1     5  BAL       Jamal Lewis  False       RB
# ...          ...     ...    ...   ...  ...               ...    ...      ...
# 6639       12665    2025      7   253  MIA      Zeek Biggers  False       DL
# 6640       12666    2025      7   254  NOR       Fadil Diggs  False       DE
# 6641       12667    2025      7   255  HOU       Luke Lachey  False       TE
# 6642       12668    2025      7   256  LAC  Trikweze Bridges  False      SAF
# 6643       12669    2025      7   257  NWE       Kobee Minor  False       DB
#
# ...
